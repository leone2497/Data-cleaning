# %% [markdown]
# <a href="https://colab.research.google.com/github/leone2497/Data-cleaning/blob/main/Calendar_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
Mattia_calendar= pd.read_excel('/content/drive/MyDrive/Dati_lavoro/Mattia calendar.xlsx')
Luigi_calendar= pd.read_excel('/content/drive/MyDrive/Dati_lavoro/Luigi calendar.xlsx')

# %%
def calendar_converter_format(start,end):
   end_up=end.str.split().str[1:3]
   start_up=start.str.split().str[1:3]
   return start_up, end_up

# %%
calendar_converter_format(Mattia_calendar['Start'],Mattia_calendar['End'])
Mattia_calendar['Start'],Mattia_calendar['End']= calendar_converter_format(Mattia_calendar['Start'],Mattia_calendar['End'])

# %%
calendar_converter_format(Luigi_calendar['Start'],Luigi_calendar['End'])
Luigi_calendar['Start'],Mattia_calendar['End']= calendar_converter_format(Luigi_calendar['Start'],Luigi_calendar['End'])

# %%
start_date = '2022-01-01'
end_date = '2024-12-31'
date_range = pd.date_range(start=start_date, end=end_date, freq='D')
hours = pd.timedelta_range(start='9 hours', end='18 hours', freq='H')
date_hour_combinations = pd.DataFrame([(date + hour) for date in date_range for hour in hours], columns=['Date'])

# %%
def convert_to_datetime(date_time_list):
    if isinstance(date_time_list, list):
        return pd.to_datetime(' '.join(date_time_list), format='%d/%m/%Y %H:%M')
    else:
        return pd.NaT

# %%
for columns in Mattia_calendar.columns:
    Mattia_calendar[columns]=Mattia_calendar[columns].apply(convert_to_datetime)

# %%
for columns in Luigi_calendar.columns:
    Luigi_calendar[columns]=Luigi_calendar[columns].apply(convert_to_datetime)

# %%
Mattia_calendar['Date']= Mattia_calendar['Start']
Luigi_calendar['Date']= Luigi_calendar['Start']

# %%
Mattia_calendar
# Out:
#                   Start                 End                Date
# 0   2024-05-07 14:00:00 2024-05-07 15:00:00 2024-05-07 14:00:00
# 1   2024-05-03 14:30:00 2024-04-23 11:00:00 2024-05-03 14:30:00
# 2   2024-04-30 10:30:00 2024-04-15 15:30:00 2024-04-30 10:30:00
# 3   2024-04-26 00:00:00 2024-04-15 12:30:00 2024-04-26 00:00:00
# 4   2024-04-25 00:00:00 2024-04-11 10:30:00 2024-04-25 00:00:00
# ..                  ...                 ...                 ...
# 489 2023-01-23 17:00:00                 NaT 2023-01-23 17:00:00
# 490 2023-01-12 14:30:00                 NaT 2023-01-12 14:30:00
# 491 2022-09-08 15:00:00                 NaT 2022-09-08 15:00:00
# 492 2022-06-20 18:00:00                 NaT 2022-06-20 18:00:00
# 493 2023-03-03 15:30:00                 NaT 2023-03-03 15:30:00
#
# [494 rows x 3 columns]

# %%
Calendario = pd.merge(date_hour_combinations , Mattia_calendar, how='outer', on='Date')

# %%
Calendario = pd.merge(Calendario , Luigi_calendar, how='outer', on='Date')

# %%
Calendario=Calendario.fillna('Free')
Calendario=Calendario.set_index('Date')

# %%
Free= Calendario.index[(Calendario== 'Free').all(axis=1)]

# %%
Free
# Out:
# DatetimeIndex(['2022-01-01 09:00:00', '2022-01-01 10:00:00',
#                '2022-01-01 11:00:00', '2022-01-01 12:00:00',
#                '2022-01-01 13:00:00', '2022-01-01 14:00:00',
#                '2022-01-01 15:00:00', '2022-01-01 16:00:00',
#                '2022-01-01 17:00:00', '2022-01-01 18:00:00',
#                ...
#                '2024-12-31 09:00:00', '2024-12-31 10:00:00',
#                '2024-12-31 11:00:00', '2024-12-31 12:00:00',
#                '2024-12-31 13:00:00', '2024-12-31 14:00:00',
#                '2024-12-31 15:00:00', '2024-12-31 16:00:00',
#                '2024-12-31 17:00:00', '2024-12-31 18:00:00'],
#               dtype='datetime64[ns]', name='Date', length=10652, freq=None)

# %%
Calendario
# Out:
#                                  Start_x End_x              Start_y End_y
# Date
# 2022-01-01 09:00:00                 Free  Free                 Free  Free
# 2022-01-01 10:00:00                 Free  Free                 Free  Free
# 2022-01-01 11:00:00                 Free  Free                 Free  Free
# 2022-01-01 12:00:00                 Free  Free                 Free  Free
# 2022-01-01 13:00:00                 Free  Free                 Free  Free
# ...                                  ...   ...                  ...   ...
# 2024-01-26 12:30:00  2024-01-26 12:30:00  Free  2024-01-26 12:30:00  Free
# 2023-09-01 12:30:00  2023-09-01 12:30:00  Free  2023-09-01 12:30:00  Free
# 2023-05-29 09:30:00  2023-05-29 09:30:00  Free  2023-05-29 09:30:00  Free
# 2023-01-12 14:30:00  2023-01-12 14:30:00  Free  2023-01-12 14:30:00  Free
# 2023-03-03 15:30:00  2023-03-03 15:30:00  Free  2023-03-03 15:30:00  Free
#
# [11152 rows x 4 columns]
